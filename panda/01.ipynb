# %%
import pandas as pd
import numpy as np

df_titanic = pd.read_csv('../train.csv')
print("Titanic dataset uploaded successfully!")
space = " \n-------------------------------------\n "

def main():
    print("head"+space)
    head = df_titanic.head()    
    print(head) # head : first files
    
    print("end head" + space + "tail")
    tail = df_titanic.tail()
    print(tail) # tail: last files  
    
    print("end tail" + space + "info")
    info = df_titanic.info()
    print(info) #info of df
    
    print("end info"+space + "describe")
    describe = df_titanic.describe()
    print(describe) # describes important data of the df
    
    print("end describe"+space+"columns")
    select_col = df_titanic[['Name', 'Age', 'Sex']]
    print(select_col.head())
    print(space)
    print(select_col.iloc[0:20])
    print(space+"Condicional")
    first_class = df_titanic['Pclass'] == 1
    print(first_class)
    print(space+"condicional multiple")
    survived = df_titanic[(df_titanic['Survived'] == 1) | (df_titanic['Pclass'] == 3)]
    print(survived)
    print("end columns" + space)

if __name__ == "__main__":
    main()
    print(space+"End titanic Data Set"+space)
# Out:
# Titanic dataset uploaded successfully!
# head
# -------------------------------------
#
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...
